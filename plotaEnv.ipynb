# %%
import serial
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', 10)

# %%
def formata_hora(s):
    dt = datetime.fromisoformat(s)
    return dt.strftime("%H:%M:%S")

# %%
df=pd.read_csv("saida_serial.csv",names=["tempo","countTHENV","valEnv"])
df
# Out:
#                          tempo  countTHENV  valEnv
# 0   2023-08-16T16:40:43.556477           0      10
# 1   2023-08-16T16:40:43.556530           0      10
# 2   2023-08-16T16:40:43.556700           0      16
# 3   2023-08-16T16:40:43.556745           0      13
# 4   2023-08-16T16:40:43.556792           0      14
# ..                         ...         ...     ...
# 77  2023-08-16T16:43:13.876202           0      13
# 78  2023-08-16T16:43:14.375694           0      30
# 79  2023-08-16T16:43:14.875488           0      15
# 80  2023-08-16T16:43:15.379057           0      11
# 81  2023-08-16T16:43:15.878833           0      13
#
# [82 rows x 3 columns]

# %%
df1 = df.copy()
df1.tempo = df.tempo.apply(formata_hora)
df1
# Out:
#        tempo  countTHENV  valEnv
# 0   16:40:43           0      10
# 1   16:40:43           0      10
# 2   16:40:43           0      16
# 3   16:40:43           0      13
# 4   16:40:43           0      14
# ..       ...         ...     ...
# 77  16:43:13           0      13
# 78  16:43:14           0      30
# 79  16:43:14           0      15
# 80  16:43:15           0      11
# 81  16:43:15           0      13
#
# [82 rows x 3 columns]

# %%
plt.figure(figsize=(18,6))
plt.plot(df1["tempo"],df1["valEnv"])
plt.xticks(df1["tempo"][::len(df1)//30],rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.plot(df1["tempo"],df1["valEnv"])
plt.xticks(df1["tempo"][::len(df)//30],rotation=90)
plt.show()
