# %%
import serial
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', 10)

# %%
def formata_hora(s):
    dt = datetime.fromisoformat(s)
    return dt.strftime("%H:%M:%S")

# %%
df=pd.read_csv("saida_serial.csv",names=["tempo","countTHENV","valEnv"])
df
# Out:
#                           tempo  countTHENV  valEnv
# 0    2023-08-16T15:51:48.391916           0      14
# 1    2023-08-16T15:51:48.391982           0      14
# 2    2023-08-16T15:51:48.392009           0      12
# 3    2023-08-16T15:51:48.392034           0      16
# 4    2023-08-16T15:51:48.392059           0      16
# ..                          ...         ...     ...
# 312  2023-08-16T15:54:22.089825           0      11
# 313  2023-08-16T15:54:22.589472           0      14
# 314  2023-08-16T15:54:23.089068           0      15
# 315  2023-08-16T15:54:23.592938           0      14
# 316  2023-08-16T15:54:24.092456           0      11
#
# [317 rows x 3 columns]

# %%
df1 = df.copy()
df1.tempo = df.tempo.apply(formata_hora)
df1
# Out:
#         tempo  countTHENV  valEnv
# 0    15:51:48           0      14
# 1    15:51:48           0      14
# 2    15:51:48           0      12
# 3    15:51:48           0      16
# 4    15:51:48           0      16
# ..        ...         ...     ...
# 312  15:54:22           0      11
# 313  15:54:22           0      14
# 314  15:54:23           0      15
# 315  15:54:23           0      14
# 316  15:54:24           0      11
#
# [317 rows x 3 columns]

# %%
plt.figure(figsize=(18,6))
plt.plot(df1["tempo"],df1["valEnv"])
plt.xticks(df1["tempo"][::len(df)//30],rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.plot(df1["tempo"],df1["valEnv"])
plt.xticks(df1["tempo"][::len(df)//30],rotation=90)
plt.show()

# %%
df1.tempo[::df2]
# Out:
# 0      15:51:48
# 2      15:51:48
# 4      15:51:48
# 6      15:51:48
# 8      15:51:49
#          ...
# 308    15:54:20
# 310    15:54:21
# 312    15:54:22
# 314    15:54:23
# 316    15:54:24
# Name: tempo, Length: 159, dtype: object

# %%
len(df)%10
# Out:
# 317
